# %%
import numpy as np
import pandas as pd

# %%
def ode(a, t):
    return a * t + 7

def ode2(a, t):
    return a*t**2 - 16*t + 7

# %%
np.random.seed(11)
t = np.arange(0, 300)
a = np.random.randn(10000)

dy_dt = [] 
for i in range(10000):
    dy_dt.append(ode2(a[i], t))

# %%
df1 = pd.DataFrame(np.array(dy_dt))
df1["a"] = a
df1.to_excel("simulated_data2.xlsx", index=False)
df1.head()
# Out:
#      0          1          2          3          4           5           6  \
# 0  7.0  -7.250545 -18.002181 -25.254907 -29.008724  -29.263631  -26.019629
# 1  7.0  -9.286073 -26.144292 -43.574657 -61.577168  -80.151825  -99.298628
# 2  7.0  -9.484565 -26.938261 -45.361086 -64.753042  -85.114128 -106.444345
# 3  7.0 -11.653319 -35.613274 -64.879867 -99.453097 -139.332964 -184.519468
# 4  7.0  -9.008285 -25.033139 -41.074562 -57.132554  -73.207116  -89.298247
#
#             7           8           9  ...            291            292  \
# 0  -19.276718   -9.034897    4.705834  ...  143496.576948  144500.509063
# 1 -119.017577 -139.308672 -160.171913  ...  -28873.947443  -29056.728001
# 2 -128.743691 -152.012168 -176.249776  ...  -45682.459962  -45980.961434
# 3 -235.012609 -290.812388 -351.918803  ... -229334.668917 -230897.553637
# 4 -105.405947 -121.530216 -137.671055  ...   -5350.550700   -5371.380639
#
# ...
